# %% [markdown]
# This notebook uses the implementation of *struc2vec* from https://github.com/sebkaz/struc2vec/tree/master

# %%
#!pip install fastdtw futures gensim numpy scipy six smart-open

# %%
import pickle, os, glob
import networkx as nx
from util import *

# %%
def delete_pkl_files(folder_path = 'struc2vec-master\\pickles'):
    """
    Deletes all .pkl files in the given folder.

    Parameters:
        folder_path (str): Path to the folder where .pkl files should be removed.
    """
    pattern = os.path.join(folder_path, "*.pickle")
    for file_path in glob.glob(pattern):
        try:
            os.remove(file_path)
            print(f"Deleted: {file_path}")
        except Exception as e:
            print(f"Error deleting {file_path}: {e}")

# %%
G = load_network()
mapping             = {old_label: i + 1 for i, old_label in enumerate(G.nodes())}
reversed_mapping    = {i + 1: old_label for i, old_label in enumerate(G.nodes())}
G                   = nx.relabel_nodes(G, mapping)
with open("data/mapping.pkl", "wb") as f:
    pickle.dump(mapping, f)
with open("data/reversed_mapping.pkl", "wb") as f:
    pickle.dump(reversed_mapping, f)

nx.write_edgelist(G, 'struc2vec-master\\graph\\graph.edgelist', data=False)

# %%
delete_pkl_files()
# Out:
# Deleted: struc2vec-master\pickles\alias_method_j-layer-0.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-1.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-10.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-11.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-12.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-13.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-14.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-15.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-16.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-2.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-3.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-4.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-5.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-6.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-7.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-8.pickle
# Deleted: struc2vec-master\pickles\alias_method_j-layer-9.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-0.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-1.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-10.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-11.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-12.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-13.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-14.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-15.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-16.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-2.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-3.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-4.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-5.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-6.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-7.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-8.pickle
# Deleted: struc2vec-master\pickles\alias_method_q-layer-9.pickle
# Deleted: struc2vec-master\pickles\amount_neighbours.pickle
# Deleted: struc2vec-master\pickles\average_weight.pickle
# Deleted: struc2vec-master\pickles\compactDegreeList.pickle
# Deleted: struc2vec-master\pickles\degrees_vector.pickle
# Deleted: struc2vec-master\pickles\distances-1.pickle
# Deleted: struc2vec-master\pickles\distances-2.pickle
# Deleted: struc2vec-master\pickles\distances-3.pickle
# Deleted: struc2vec-master\pickles\distances-4.pickle
# Deleted: struc2vec-master\pickles\distances_nets_graphs.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-0.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-1.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-10.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-11.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-12.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-13.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-14.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-15.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-16.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-2.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-3.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-4.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-5.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-6.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-7.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-8.pickle
# Deleted: struc2vec-master\pickles\distances_nets_weights-layer-9.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-0.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-1.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-10.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-11.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-12.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-13.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-14.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-15.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-16.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-2.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-3.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-4.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-5.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-6.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-7.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-8.pickle
# Deleted: struc2vec-master\pickles\graphs-layer-9.pickle
# Deleted: struc2vec-master\pickles\nets_weights_alias_method_j.pickle
# Deleted: struc2vec-master\pickles\nets_weights_alias_method_q.pickle
# Deleted: struc2vec-master\pickles\split-degreeList-1.pickle
# Deleted: struc2vec-master\pickles\split-degreeList-2.pickle
# Deleted: struc2vec-master\pickles\split-degreeList-3.pickle
# Deleted: struc2vec-master\pickles\split-degreeList-4.pickle
# Deleted: struc2vec-master\pickles\split-vertices-1.pickle
# Deleted: struc2vec-master\pickles\split-vertices-2.pickle
# Deleted: struc2vec-master\pickles\split-vertices-3.pickle
# Deleted: struc2vec-master\pickles\split-vertices-4.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-0.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-1.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-10.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-11.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-12.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-13.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-14.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-15.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-16.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-2.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-3.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-4.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-5.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-6.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-7.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-8.pickle
# Deleted: struc2vec-master\pickles\weights_distances-layer-9.pickle

# %%
# !python struc2vec-master/src/main.py --input struc2vec-master/graph/graph.edgelist --output data/embedding.emb --num-walks 50 --walk-length 100 --window-size 16 --dimensions 128 --iter 50 --directed --OPT1 True --OPT2 True --OPT3 True
