# %% [markdown]
# # 02805 Social graphs and interactions, Fall 20205 - Assignment 1
#
# #### Søren Stange, s204229
# #### Freja Tusindfryd Dollas, s204248

# %%
#import all necessary libraries and modules
import networkx as nx 
import matplotlib.pyplot as plt
import numpy as np
import pickle, requests, os, re

# %% [markdown]
# ## Assignment 1.1: Exploring WS and BA models

# %% [markdown]
# #### $\textbf{Did you really read the text?}$

# %% [markdown]
# ##### Question: What's the problem with random networks as a model for real-world networks according to the argument in section 3.5?
#
# Answer: In random networks the difference between the most connected node and the least connected node is very small. This is in contrast to real world phenomena, where (in the social network for instance) the most connected nodes (people) are connected to many thousands of other nodes, and the least connected nodes are far from this. We are missing the hubs which are nodes who connect to many other nodes. This can be seen in chapter 3.5 Image 3.6, where the actual degree distribution of a real network, does not at all reflect the idealized version of the random network.

# %% [markdown]
# ##### Question: List the four regimes that characterize random networks as a function of $<k>$.
#
# Answer: The four regimes that characterize random networks are:
# 1) Subcritical Regime | Here the average degree of a node <k> < 1. This results in a network consisting of many tiny clusters. That is, a highly disconnected network of nodes. The largest cluster in this domain is roughly of size ln N
# 2) Critical point | Here we have <k> = 1. This lead s to a significant jump in the size of the largest cluster in the network. We still don't have a giant component, however the largest cluster is rougly of size N^(2/3).
# 3) Supercritical Regime | Here we have <k> > 1. In this regime we start to have giant component. The size of the largest component is roughly (p-1/N)N. In this regime we will have multiple connected components coexisting with the giant component.
# 4) Connected Regime | Here we have <k> > ln N. In this regime the giant component absorbs all other nodes, leaving (almost) no isolated nodes.

# %% [markdown]
# ##### Question: According to the book, why is it a problem for random networks (in terms of being a model for real-world networks) that the degree-dependent clustering $C(k)$ decreases as a function of $k$ in real-world networks?
#
# Answer: Because in the random network we expect the culstering coefficient to decrease as N grows. This is in contrast to real networks where the clustering coefficient decreases as a function of k. This means that the clustering coefficient in real networks are more or less independent of the size of the network.

# %% [markdown]
# #### $\textbf{WS Edition}$

# %% [markdown]
# ##### Question: First, let's use networkx to play around with WS graphs. Use nx.watts_strogatz_graph to generate 3 graphs with 500 nodes each, average degree = 4, and rewiring probablity $p=0, 0.1,$ and $1$. Calculate the average shortest path length $<d>$ for each one.

# %%
# Answer:
N, k = 500, 4
p1,p2,p3 = 0.0, 0.1, 1.0
G1 = nx.watts_strogatz_graph(N, k, p=p1, seed=0)
G2 = nx.watts_strogatz_graph(N, k, p=p2, seed=1)
G3 = nx.watts_strogatz_graph(N, k, p=p3, seed=2)
print(f'WS graph with rewiring probability p={p1} average shortest path: {nx.average_shortest_path_length(G1):.2f}')
print(f'WS graph with rewiring probability p={p2} average shortest path: {nx.average_shortest_path_length(G2):.2f}')
print(f'WS graph with rewiring probability p={p3} average shortest path: {nx.average_shortest_path_length(G3):.2f}')
# Out:
# WS graph with rewiring probability p=0.0 average shortest path: 62.88
# WS graph with rewiring probability p=0.1 average shortest path: 7.95
# WS graph with rewiring probability p=1.0 average shortest path: 4.75

# %% [markdown]
# ##### Question: Describe what happens to the network when $p=1$.
#
# Answer: In the case where the rewiring probability hits 1 ($p=1$), we essentially get a random network, as all of the edges will have been rewired randomly.

# %% [markdown]
# ##### Question: Generate a lot of networks with different values of $p$. You will notice that paths are short when $p$ is close to one and they are long when $p=0$. What's the value of $p$ for which the average shortest path length get close to the short paths we find in a fully randomized network.

# %%
# Answer:
M = 20
P = np.arange(start= 0, stop = 1, step = 1/M)
for i, pi in enumerate(P):
    G = nx.watts_strogatz_graph(N, k, p = pi, seed=i)
    print(f'Network p = {pi:.2f} average shortest path: {nx.average_shortest_path_length(G):.2f}')
# Out:
# Network p = 0.00 average shortest path: 62.88
# Network p = 0.05 average shortest path: 9.75
# Network p = 0.10 average shortest path: 7.44
# Network p = 0.15 average shortest path: 6.70
# Network p = 0.20 average shortest path: 6.16
# Network p = 0.25 average shortest path: 5.69
# Network p = 0.30 average shortest path: 5.42
# Network p = 0.35 average shortest path: 5.24
# Network p = 0.40 average shortest path: 5.24
# Network p = 0.45 average shortest path: 5.07
# Network p = 0.50 average shortest path: 4.96
# Network p = 0.55 average shortest path: 4.91
# Network p = 0.60 average shortest path: 4.88
# Network p = 0.65 average shortest path: 4.84
# Network p = 0.70 average shortest path: 4.77
# Network p = 0.75 average shortest path: 4.76
# Network p = 0.80 average shortest path: 4.76
# Network p = 0.85 average shortest path: 4.76
# Network p = 0.90 average shortest path: 4.75
# Network p = 0.95 average shortest path: 4.78

# %% [markdown]
# Answer:
#
# We see at $p \in \left[0.6, 1.0\right[$ that the average shortest path here are close to indistinguishable from the total randomized network.

# %% [markdown]
# ##### Question: Let's investigate this behavior in detail. Generate 50 networks with $N = 500, <k> = 4$, for each of $p \in \left\{ 0, 0.01, 0.03, 0.05, 0.1, 0.2\right\}$. Calculate the average of $<d>$ as well as the standard deviation over the 50 networks, to create a plot that shows how the path length decreases very quickly with only a little fraction of re-wiring. Use the standard deviation to add errorbars to the plot. My version of the plot is below (since a picture's worth 1000 words).

# %%
# Answer:
P = [0, 0.01, 0.03, 0.05, 0.1, 0.2]
N, k = 500, 4
M = 50
avg = []
std = []
for i, pi in enumerate(P):
    now = []
    for _ in range(M):
        G = nx.watts_strogatz_graph(N, k, p = pi)
        now.append(nx.average_shortest_path_length(G))
    avg.append(np.average(now))
    std.append(np.std(now))

plt.figure(figsize=(8,6))
plt.errorbar(P, avg, yerr=std, fmt='o-', capsize=5, 
             ecolor='gray', elinewidth=1.5, markerfacecolor='blue', markersize=8)

plt.title("Average Shortest Path Length in Watts-Strogatz Graphs", fontsize=14)
plt.xlabel("Rewiring Probability (p)", fontsize=12)
plt.ylabel("Average Shortest Path Length", fontsize=12)

plt.xticks(P)  
plt.grid(True, linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Question: Imagine that you put this plot in an assignment. Write a figure caption that explains to the reader what the plot shows (which variables, etc) and what's interesting about it.

# %% [markdown]
# Answer: Figure 1: The average shortest path length ⟨d⟩ as a function of rewiring probability p in Watts–Strogatz graphs with N=500 nodes and average degree ⟨k⟩=4. The average shortest path length is found as the mean over 50 generated networks, and the error bars are the standard deviation. It's clear that when p=0 path lengths are very long (around 62), while a smaller adjustment of p (p=0.01) makes the average shortest path length much shorter (around 25). A larger p (0.03, 0.05, 0.1 and 0.2) attains still smaller average shortest path lengths that approach the behaviour of random netwroks, p=1. It illustrates that a small amoundt of randomness in a network can drastically reduce distance between nodes.

# %% [markdown]
# #### $\textbf{BA Edition}$

# %% [markdown]
# ##### Question: What are the three slope dependent regimes of complex networks with power-law degree distributions? Briefly describe each one. (You will have to skim chp 4.7 to answer this one).
#
# Answer: The three slope dependent regimes of complex networks with power-law degree distributions depend on the degree exponent γ and they are as follows:
# - Anomalous Regime (γ ≤ 2): Hubs grows faster than the network itself, which means that for larger networks the networks \"runs out\" of nodes to connet to while the average number of connections <k> goes to infinity.
#
# - Scale-Free Regime (2 ‹ γ ‹ 3):  The average degree is finite however the spread is so large that the variance is infinite, and so there are massive hubs which makes the networks ultra-small. With larger N hubs grow bigger but the number of connected nodes shrink.
#
# - Random Network Regime (γ › 3): Average degree and variance are finite, so not as many hubs, and difficult to distinguish from random networks.

# %% [markdown]
# ##### Question: What are the three regimes we find in non-linear preferential attachement? (chapter 5) Briefly describe each one.
#
# Answer: The three non-linear preferential attachment regimes depend on α and they are as follows:
# - No Preferential Attachment (α=0): The networks follows a exponential degree distribution, and is similar to a random network.
#
# - Sublinear Preferential Attachment (0 < α < 1): New nodes favor more connected ones, however sublinear preferential attachment limits the size and number of hubs.
#
# - Superlinear Preferential Attachment (α > 1): New nodes favor more connected ones creating super hubs, so that high-degree nodes get more connections while small nodes remain small.

# %% [markdown]
# ##### Question: First create a graph consisting of a single link. (You can call the nodes anything, but I would simply use integers as names).
#
# (following quetions are omitted and instead here is the full code creating the network)

# %%
# Answer: Building a 100 node network
import random
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np


G = nx.Graph()
G.add_edge(0, 1)

node_list = [0, 1]


while len(G.nodes) < 100:
    new_node = len(G.nodes)
    new_node_conn = random.choice(node_list)
    G.add_edge(new_node, new_node_conn)

    node_list.append(new_node)
    node_list.append(new_node_conn)

# %% [markdown]
# ##### Question: Plot the network.

# %%
# Answer:
plt.figure(figsize=(6,6))
nx.draw(G, node_size=30, node_color="skyblue", edge_color="gray", with_labels=False)
plt.title("BA network (100 nodes)")
plt.show()

# %% [markdown]
# Figure 2: The Barabasi-Albert network generated with 100 nodes.

# %% [markdown]
# ##### Question: Add more nodes until you have a 5000 node network.

# %%
# Answer: Expanding to 5000 node network
while len(G.nodes) < 5000:
    new_node = len(G.nodes)
    new_node_conn = random.choice(node_list)
    G.add_edge(new_node, new_node_conn)

    node_list.append(new_node)
    node_list.append(new_node_conn)

# %% [markdown]
# ##### Question: What's the maximum and minimum degree?

# %%
# Answer:
degrees = dict(G.degree())
max_deg = max(degrees.values())
min_deg = min(degrees.values())

print("Maximum degree of network:", max_deg)
print("Minimum degree of network:", min_deg)
# Out:
# Maximum degree of network: 102
# Minimum degree of network: 1

# %% [markdown]
# This means that the most well-connected notes has 102 connections while some nodes only have 1 connection. This underlines the nature of the network where new nodes are more probable to connect with nodes with many connections.

# %% [markdown]
# ##### Question: Now, bin the degree distribution using numpy.histogram.,

# %%
# Answer:
degree_values = list(degrees.values())
hist, bins = np.histogram(degree_values, bins=range(1, max_deg+2))

bin_cent = (bins[:-1] + bins[1:]) / 2

# %% [markdown]
# ##### Question: Plot the distribution. Plot it with both linear and log-log axes.

# %%
# Answer:
plt.figure()
plt.scatter(bin_cent, hist, color="blue", s=20)
plt.xlabel("Degree")
plt.ylabel("Count")
plt.title("Degree distribution")
plt.show()

# Log-log scale (points)
plt.figure()
plt.scatter(bin_cent, hist, color="red", s=20)
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Degree (log)")
plt.ylabel("Count (log)")
plt.title("Degree distribution (log-log scale)")
plt.show()

# %% [markdown]
# Figure 3: Degree distribution linear scale: Point plot of the distribution of degrees for all nodes in the network with N=5000. Each point shows the number of nodes that have a specific degree. It is clear that most nodes have a low degree while a few nodes have a very high degree.
#
# Figure 4: Degree distribution log-log scale: Point plot of the distribtion of degrees for all nodes in the network with N=5000 plotted with logartihmic axes. The trend is somewhat linear and illustrates the power law (few have high degree, many have low degree)

# %% [markdown]
# #### $\textbf{Explain your process in words}$

# %% [markdown]
# ##### Question: Document how you crawled the network.
# Answer:
#
# $\textbf{Steps taken}$: We reused our code for downloading wikipedia pages from week 1. We used this code to download all of the text on the $\textit{List of mainstream rock performers}$ wikipedia-page (https://en.wikipedia.org/wiki/List_of_mainstream_rock_performers). We then used a regular expression in order to extract all the links on the wikipedia page. We then cleaned the titles of the links by replacing blank spaces with underscores, such that these could now be used in our wikipedia-page downloader function. We removed the very first link,. as this linked to $\textit{rock music}$ (https://en.wikipedia.org/wiki/Rock_music), which we didn't want in our data set. Some of the links we found were on the format 'title1 | title2'. We handled this by taking title1, as we found that this was the one linking to the musician. Now we had a comprehensive list of rock performers, which we iterated over, downloading all the text of their wikipedia page. We saved all of this data in a .pkl file in a list of dictionaries on the form {'page_name' : 'The_Rolling_Stones', 'text': '...'}.
#
#
# $\textbf{Most difficult part of the process}$: The most difficult/annoying part of the process was to handle the special characters. These gave a headache at first, when trying to solve it manually. However, with the help of LLMs we managed to get through it.
#
#
# $\textbf{How we used LLMs for help}$: We used ChatGPT for help of the regular expressions to be used to extract all the links from the wiki text. That is, ChatGPT helped us get the search pattern: r'\[\[([^\]]+)\]\]', which extracts everything in between two closed brackets ( [[Text here is extracted]] ). We also got help from ChatGPT to handle the special characters such as '-', 'Ü', etc. as there were some problems with the encoding when interacting with the wikipedia api.
#
#
# $\textbf{How would we do it differently in the future}$: We didn't really have a "gameplan" going in, beacuse we had no experience dealing with such a problem. In the feature we would be much more aware of potential problems with special characters and handle them systematically () and find a way to deal with non-important links - that is have a clearer strategy for what we actually wanted to keep.

# %% [markdown]
# #### $\textbf{Simple network statistics and analysis}$

# %%
# Download the data from github if not already downloaded
filename = "assignment_1_rock_bands.pkl"

url = "https://raw.githubusercontent.com/sorenstange/02805_Social_graphs_and_interactions/main/assignment_1_rock_bands.pkl"

# Step 1: Check if file exists
if not os.path.exists(filename):
    # Download the file if it does not exist
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, "wb") as f:
            f.write(response.content)
        print("File downloaded successfully.")
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
else:
    print("File already exists. Skipping download.")

# Step 2: Load the .pickle file
with open(filename, "rb") as f:
    data = pickle.load(f)
# Out:
# File already exists. Skipping download.

# %%
# Declare helper functions
def clean_links(links):
    arr = []
    for l in links:
        match = re.search(r'|', l)
        if match:
            splits = l.split(r'|')
            arr.append(splits[0].replace(' ', '_'))
        else:
            arr.append(l.replace(' ', '_'))
    return arr

def analyze_node(data_point):
    Node = data_point['page_name']
    text = data_point['content']
    words = len(text.split())
    links_to = re.findall(r'\[\[([^\]]+)\]\]', text)
    links_to = clean_links(links_to)
    return Node, links_to, words

def create_network(data):
    G = nx.DiGraph()
    Nodes = list(set([data_point['page_name'] for data_point in data]))
    Nodes.remove('AllMusic')
    for data_point in data:
        Node, links_to, words = analyze_node(data_point)
        if Node == 'AllMusic':
            continue
        G.add_node(Node, words=words)
        for links_to_node in links_to:
            if links_to_node in Nodes:
                G.add_edge(Node, links_to_node)
    
    # Extract the largest component
    components = nx.weakly_connected_components(G)
    largest = max(components, key=len)
    G = G.subgraph(largest).copy()
    return G

    
def compare_degree_distributions(G, bins=30):
    plt.style.use("seaborn-v0_8-whitegrid")
    plt.rcParams.update({
        "font.size": 12,
        "axes.titlesize": 14,
        "axes.labelsize": 12,
        "xtick.labelsize": 11,
        "ytick.labelsize": 11,
        "legend.fontsize": 11,
        "figure.titlesize": 16
    })
    
    # Original network stats
    n = G.number_of_nodes()
    m = G.number_of_edges()

    # Generate random directed graph
    G_random = nx.gnm_random_graph(n, m, directed=True)

    # Generate scale-free directed graph
    G_sf = nx.scale_free_graph(n)
    #G_sf = nx.DiGraph(G_sf)  # remove parallel edges/self-loops

    # Degree sequences
    in_deg_original = [deg for _, deg in G.in_degree()]
    out_deg_original = [deg for _, deg in G.out_degree()]
    out_deg_random = [deg for _, deg in G_random.degree()]
    in_deg_sf = [deg for _, deg in G_sf.degree()]

    # Define shared bin edges
    in_max = max(max(in_deg_original), max(in_deg_sf))
    out_max = max(max(out_deg_original), max(out_deg_random))

    in_bins = np.linspace(0, in_max, bins+1)
    out_bins = np.linspace(0, out_max, bins+1)

    # Plot
    fig, axes = plt.subplots(2, 2, figsize=(12, 8))

    # In-degree plots (shared bins)
    axes[0,0].hist(in_deg_original, bins=in_bins, color="#1f77b4", alpha=0.8, edgecolor="black")
    axes[0,0].set_title("Original In-degree distribution")

    axes[1,0].hist(in_deg_sf, bins=in_bins, color="purple", alpha=0.8, edgecolor="black")
    axes[1,0].set_title("Scale-free degree distribution")

    # Out-degree plots (shared bins)
    axes[0,1].hist(out_deg_original, bins=out_bins, color="#ff7f0e", alpha=0.8, edgecolor="black")
    axes[0,1].set_title("Original Out-degree distribution")
    axes[1,1].hist(out_deg_random, bins=out_bins, color="green", alpha=0.8, edgecolor="black")
    axes[1,1].set_title("Random Graph degree distribution")

    for ax in axes.flat:
        ax.set_xlabel("Degree")
        ax.set_ylabel("Frequency")

    fig.suptitle("Degree Distribution Comparison", fontsize=16, weight="bold")
    fig.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()


G = create_network(data)

# %% [markdown]
# ##### Question: What is the number of nodes in the network?

# %%
# Answer:
print(f'Answer: There are {len(G.nodes())} nodes in the network.\n')
# Out:
# Answer: There are 484 nodes in the network.

# %% [markdown]
# ##### Question: What is the number of links in the network?

# %%
# Answer:
print(f'Answer: There are {len(G.edges())} links in the network.\n')
# Out:
# Answer: There are 7321 links in the network.

# %% [markdown]
# ##### Question: Plot the in and out-degree distributions for the entire network. What do you observe? Can you explain why the in-degree distribution is different from the out-degree distribution?
#
# Answer: See description on figures below. Figure 5 and 6 picture the in- and out-degree distributions and they are different in the way that: Most nodes have a low number of in connections while few have a high in-degree and the out-degree distribution is more bell-shaped with degrees centered around 15 ish and less extreme high values. This is probably because the number of links in articles is around the same number of links (out degree) while the number of articles referencing certain performers (in degree) vary highly depending on how "important" that performer is.

# %%
# Answer:
compare_degree_distributions(G, bins = 30)
# Out:
# /Users/frejatusindfryd/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# Figure 5 (upper left): Original in-degree distribution: Right-skewed distribution with most nodes having a relatively lowe in-degree with a few having high in-degrees.
#
# Figure 6 (upper right): Original out-degree distribution: Right-skewed distribution with most nodes having a relatively low out-degree with a few having high out-degrees.
#
# Figure 7 (lower left): Scale-free degree distribution: Right-skewed distribution but somehow bell-shaped with most nodes having low in-degree and a few having high in-degrees.
#
# Figure 8 (lower right): Random Graph degree distribution: Somewhat symmetrical distribution centered around mean with no extreme values.
#
# $\textbf{Question: Compare the out-degree distribution to a random network with the same number of nodes and links.}$
#
# See figure 6 and 8: In our network the out-degrees of some nodes are very large creating a long tail in the distribution which is far from the symmetrical distribution and near-average number of degrees for nodes in the random network.
#
# $\textbf{Question: Compare the in-degree distribution to a scale-free network with the same number of nodes.}$
#
# See figure 5 and 7: Both our network and the scale-free network has similar distribution of in-degrees. This means that our network tends to favor nodes that already have a high degree.

# %% [markdown]
# ##### Question: Who are the top 5 most connected performers (Report results for in-degrees and out-degrees, that is, who has highest in-degree, who has highest out-degree)?

# %%
sorted_nodes = sorted(G.in_degree(), key=lambda x: x[1], reverse=True)
top5_in = sorted_nodes[:5]

sorted_nodes = sorted(G.out_degree(), key=lambda x: x[1], reverse=True)
top5_out = sorted_nodes[:5]

print("\033[1mTop 5 most connected performers (In-degree):\033[0m")
print(f'{"Performer":<40} {"In-degree":>10}')
print('-' * 52)
for performer, degree in top5_in:
    print(f'{performer:<40} {degree:>10}')

print("\n\033[1mTop 5 most connected performers (Out-degree):\033[0m")
print(f'{"Performer":<40} {"Out-degree":>10}')
print('-' * 52)
for performer, degree in top5_out:
    print(f'{performer:<40} {degree:>10}')
# Out:
# Top 5 most connected performers (In-degree):
# Performer                                 In-degree
# ----------------------------------------------------
# Led_Zeppelin                                    119
# Bob_Dylan                                        95
# Queen_(band)                                     88
# Metallica                                        85
# David_Bowie                                      83
#
# Top 5 most connected performers (Out-degree):
# Performer                                Out-degree
# ----------------------------------------------------
# Alice_in_Chains                                  74
# Deep_Purple                                      71
# Black_Sabbath                                    60
# Def_Leppard                                      52
# Bryan_Adams                                      51

# %% [markdown]
# ##### Comment on your findings. Is this what you would have expected?
# The bands with mosst in-degrees are very iconic and very well-known bands, and it makes sense that a lot of other bands sites reference them (maybe other bands have done covers, taken inspiration, done concerts in same places etc.) and vice versa for out-degree.

# %% [markdown]
# ##### Question: What are the 10 pages with the longest wiki entries? (use the length of content attribute to figure this one out)?

# %%
# Answer:
nodes_with_words = [(node, data['words']) for node, data in G.nodes(data=True)]
top10 = sorted(nodes_with_words, key=lambda x: x[1], reverse=True)[:10]
print("\n\033[1mTop 10 pages with longest wiki entries:\033[0m")
print(f'{"Performer":<40} {"Words":>10}')
print('-' * 52)
for performer, words in top10:
    print(f'{performer:<40} {words:>10}')
# Out:
# Top 10 pages with longest wiki entries:
# Performer                                     Words
# ----------------------------------------------------
# Bob_Dylan                                     30647
# Guns_N'_Roses                                 29710
# Paul_McCartney                                27330
# Queen_(band)                                  27170
# The_Rolling_Stones                            26186
# David_Bowie                                   24912
# Elton_John                                    24904
# U2                                            24877
# The_Beach_Boys                                24816
# Elvis_Presley                                 24710

# %% [markdown]
# As for the most connected performers, we once again see that the more iconic and well known rock performers have the longest wiki text.

# %% [markdown]
# #### Let's build a simple visualization of the network

# %%
# Answer:
### Insert code here
G_undirected = G.to_undirected().copy()

pos = nx.spring_layout(G_undirected)

words = [data['words'] for _, data in G_undirected.nodes(data=True)]
norm = plt.Normalize(vmin=min(words), vmax=max(words))
cmap = plt.cm.summer
colors = cmap(norm(words))

degrees = np.array([deg for _, deg in G_undirected.degree()])
max_node_size, min_node_size = 400, 10
normalized_degrees = (degrees-np.min(degrees))/(np.max(degrees)-np.min(degrees))
node_sizes = min_node_size + normalized_degrees * (max_node_size - min_node_size)

fig, ax = plt.subplots(figsize=(16,10))
nx.draw_networkx_nodes(G_undirected, pos, ax=ax,
                               node_size=node_sizes,
                               node_color=colors,
                               edgecolors="black", linewidths=0.5)
nx.draw_networkx_edges(G_undirected, pos, ax=ax,
                               edge_color="#8A8A8A",
                               alpha=0.6, width=1)
ax.set_title('Rock performers network', fontsize=18)
ax.axis("off")

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label("Number of words", fontsize=14)

plt.show()

# %% [markdown]
# Figure 9: The rock performers network plotted. Node size depends on the degree of the rock performer, that is larger node = higher degree. The color of the nodes correspond to the the length of the wiki text associated with the rock performer. We see that the rock performers with the highest degree (biggest nodes) are also those performers who tend to have the longest wiki text. This makes good sense, as the longer the text is, the more links to other rock performers there can be.

# %% [markdown]
# ##### THE END

# %% [markdown]
# Contribution: We have each contributed equally to all parts of the assignment. If it is necessary to elaborate it can be somewhat fair to divide as follows:
# - WS: Søren Stange
# - BA: Freja Tusindfryd Dollas
# - Performers: Both
