# %% [markdown]
# ### Research Questions:
# - *Which universe has a more centralized social structure?*. FREJA
#     * Notes:
#         - Possible methods:
#             - Degree Centralization (Freeman Centralization)
#             - Betweenness Centralization
#             - Eigenvector Centralization
#             - PageRank Distribution Comparison
#             - Core–Periphery Structure Fit
#         - Possible findings: Harry potter is more centrilized as it is a story about the life of one boy. It is more statical as it rouglhy only is in one location (Hogwarts). This is in contrast to Lord of the Rings, as this is a journey through time. We do however follow one central character, but there is a larger shift in who is in the story, in contrast to Harry Potter.
#
# - *Is one universe more hierarchical or egalitarian in terms of interactions?*. FREJA
#     * Notes:
#         - Possible methods:
#             - Directed Acyclic Hierarchy Scores
#             - Social Stratification via Stochastic Block Models (SBM)
#             - Role-based structural equivalence
#             - Gini Coefficients of Centrality Distributions
#             - Hierarchy Index (Blondel, 2008)
#             - Global Reaching Centrality (GRC)
#
# - *Can we identify parallel roles purely from network structure, without narrative context?* SØREN
#     * Notes:
#         - Node2vec algorithm for finding nodes which are similar in one universe.
#         - Struc2vec algorithm for finding nodes across networks which occupy similar structural positions.
#         - Maybe: Compute a vector of structural properties (In-degree, Out-degree, Closeness, Eigenvector / pageRank, Clustering coefficient, triadic position, etc.) for each characters, and use clustering algorithms (k-means, hierarchical clustering, Gaussian mixture models)
# - *Which universe is “happier” in its social graph?*
#     * Notes:
#         - Methods:
#             - Sentiment analysis (Nodes)
#             - Edge level sentiment. Find the sentences where the characters are mentioned in the hyperlinks, and use this text for sentiment.
#             - Emotion Lexicon Analysis
#             - Topic Modeling + Sentiment
# - *Is the Lord of the Rings network more polarized than the Harry Potter one?*
#     * Notes:
#         - Methods:
#             - Structural Polarization via Modularity
#             - Assortativity (Homophily)
#             - Sentiment Polarity Between Groups'
#             - Embedding-Based Polarization
